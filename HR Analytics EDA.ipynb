# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
hrtrain=pd.read_csv('train_LZdllcl.csv')

# %%
hrtest=pd.read_csv('test_2umaH9m.csv')

# %%
hrtrain.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                  8              1            0                  49
# ...

# %%
hrtest.head()
# Out:
#    employee_id         department     region   education gender  \
# 0         8724         Technology  region_26  Bachelor's      m
# 1        74430                 HR   region_4  Bachelor's      f
# 2        72255  Sales & Marketing  region_13  Bachelor's      m
# 3        38562        Procurement   region_2  Bachelor's      f
# 4        64486            Finance  region_29  Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   24                   NaN
# 1               other                1   31                   3.0
# 2               other                1   31                   1.0
# 3               other                3   31                   2.0
# 4            sourcing                1   30                   4.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score
# 0                  1              1            0                  77
# ...

# %%
# average age of gender
hrtrain.gender.value_counts()
# Out:
# m    38496
# f    16312
# Name: gender, dtype: int64

# %%
# cross tabulation of education and gender
pd.crosstab(hrtrain.gender,hrtrain.education)
# Out:
# education  Bachelor's  Below Secondary  Master's & above
# gender
# f               10854              289              4778
# m               25815              516             10147

# %%
# cross tabulation of is_promoted and awardswon
pd.crosstab(hrtrain.is_promoted,hrtrain['awards_won?'])
# Out:
# awards_won?      0    1
# is_promoted
# 0            49429  711
# 1             4109  559

# %%
# how many types of recruitment channel is there
hrtrain.recruitment_channel.value_counts()
# Out:
# other       30446
# sourcing    23220
# referred     1142
# Name: recruitment_channel, dtype: int64

# %%
# cross tabulation of gender and KPIs_met>80%
pd.crosstab(hrtrain.gender,hrtrain['KPIs_met >80%'])
# Out:
# KPIs_met >80%      0      1
# gender
# f              10123   6189
# m              25394  13102

# %%
# cross tabulation of recruitment channel and is_promoted
pd.crosstab(hrtrain.is_promoted,hrtrain['recruitment_channel'])
# Out:
# recruitment_channel  other  referred  sourcing
# is_promoted
# 0                    27890      1004     21246
# 1                     2556       138      1974

# %%
# cross tabulation of recruitment channel and awardswon
pd.crosstab(hrtrain.recruitment_channel,hrtrain['awards_won?'])
# Out:
# awards_won?              0    1
# recruitment_channel
# other                29720  726
# referred              1112   30
# sourcing             22706  514

# %%
# cross tabulation of department  and is_promoted
pd.crosstab(hrtrain.department,hrtrain['is_promoted'])
# Out:
# is_promoted            0     1
# department
# Analytics           4840   512
# Finance             2330   206
# HR                  2282   136
# Legal                986    53
# Operations         10325  1023
# Procurement         6450   688
# R&D                  930    69
# Sales & Marketing  15627  1213
# Technology          6370   768

# %%
# cross tabulation of department  and awardswon
pd.crosstab(hrtrain.department,hrtrain['awards_won?'])
# Out:
# awards_won?            0    1
# department
# Analytics           5222  130
# Finance             2466   70
# HR                  2373   45
# Legal               1014   25
# Operations         11086  262
# Procurement         6967  171
# R&D                  978   21
# Sales & Marketing  16479  361
# Technology          6953  185

# %%
# Bar Graphs

# %%
# Bar graph on gender
hrtrain.gender.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# Bar graph on education and gender
pd.crosstab(hrtrain.gender,hrtrain.education).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='gender'>

# %%
# Bar graph on is_promoted and awardswon
pd.crosstab(hrtrain.is_promoted,hrtrain['awards_won?']).plot(kind='bar',logy=True)
# Out:
# <AxesSubplot:xlabel='is_promoted'>

# %%
# Bar graph on recruitment channel
hrtrain.recruitment_channel.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# Bar graph on gender and KPIs_met>80%
pd.crosstab(hrtrain.gender,hrtrain['KPIs_met >80%']).plot(kind='bar',logy=True)
# Out:
# <AxesSubplot:xlabel='gender'>

# %%
# Bar graph on recruitment channel and is_promoted
pd.crosstab(hrtrain.recruitment_channel,hrtrain['is_promoted']).plot(kind='bar',logy=True)
# Out:
# <AxesSubplot:xlabel='recruitment_channel'>

# %%
# Bar graph on recruitment channel and awardswon
pd.crosstab(hrtrain.recruitment_channel,hrtrain['awards_won?']).plot(kind='bar',logy=True)
# Out:
# <AxesSubplot:xlabel='recruitment_channel'>

# %%
# Bar graph on department  and is_promoted
pd.crosstab(hrtrain.department,hrtrain['is_promoted']).plot(kind='bar',logy=True)
# Out:
# <AxesSubplot:xlabel='department'>

# %%
# Bar graph on department  and awardswon
pd.crosstab(hrtrain.department,hrtrain['awards_won?']).plot(kind='bar',logy=True)
# Out:
# <AxesSubplot:xlabel='department'>

# %%
# Pie chart on Gender
hrtrain.gender.value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='gender'>

# %%
# Pie chart on Region
hrtrain.region.value_counts().plot(kind='pie',radius=4)
# Out:
# <AxesSubplot:ylabel='region'>

# %%
# Pie chart on Department
hrtrain.department.value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='department'>
